# %% [markdown]
# **ADDING THE HIDDEN LAYER TO THE AUTOENCODER AND VISUALIZING THE DATA**

# %%
from keras.layers import Input, Dense
from keras.models import Model
import matplotlib.pyplot as plt

# %%
# Define the size of encoded representations and the additional hidden layer size
encoding_dim = 32
hidden_dim = 64

# %%
# Input placeholder
input_img = Input(shape=(784,))

# %%
# First Encoding Layer
encoded1 = Dense(hidden_dim, activation='relu')(input_img)
# Second Encoding Layer
encoded2 = Dense(encoding_dim, activation='relu')(encoded1)

# %%
# First Decoding layer
decoded1 = Dense(hidden_dim, activation='relu')(encoded2)
# Second Decoding layer
decoded = Dense(784, activation='relu')(decoded1)

# %%
# Creating the autoencoder model
autoencoder = Model(input_img, decoded)

# %%
# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
# Loading and preprocessing the data
from keras.datasets import fashion_mnist
import numpy as np

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
# Train the autoencoder
history = autoencoder.fit(x_train, x_train, epochs=25, batch_size=256, shuffle=True, validation_data=(x_test, x_test))
# Out:
# Epoch 1/25
# 235/235 [==============================] - 5s 16ms/step - loss: 0.8519 - val_loss: 0.6816
# Epoch 2/25
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6361 - val_loss: 0.6351
# Epoch 3/25
# 235/235 [==============================] - 3s 11ms/step - loss: 0.5937 - val_loss: 0.5758
# Epoch 4/25
# 235/235 [==============================] - 3s 11ms/step - loss: 0.5677 - val_loss: 0.5451
# Epoch 5/25
# 235/235 [==============================] - 3s 12ms/step - loss: 0.5385 - val_loss: 0.5186
# Epoch 6/25
# 235/235 [==============================] - 5s 21ms/step - loss: 0.5058 - val_loss: 0.5007
# Epoch 7/25
# 235/235 [==============================] - 5s 21ms/step - loss: 0.4901 - val_loss: 0.4949
# Epoch 8/25
# 235/235 [==============================] - 5s 23ms/step - loss: 0.4873 - val_loss: 0.5112
# Epoch 9/25
# 235/235 [==============================] - 3s 12ms/step - loss: 0.5046 - val_loss: 0.4876
# Epoch 10/25
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4717 - val_loss: 0.4682
# Epoch 11/25
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4678 - val_loss: 0.4601
# Epoch 12/25
# 235/235 [==============================] - 4s 15ms/step - loss: 0.4546 - val_loss: 0.4550
# Epoch 13/25
# 235/235 [==============================] - 3s 11ms/step - loss: 0.4523 - val_loss: 0.4529
# Epoch 14/25
# 235/235 [==============================] - 3s 11ms/step - loss: 0.4508 - val_loss: 0.4770
# Epoch 15/25
# 235/235 [==============================] - 3s 11ms/step - loss: 0.4541 - val_loss: 0.4546
# Epoch 16/25
# 235/235 [==============================] - 3s 12ms/step - loss: 0.4545 - val_loss: 0.4542
# Epoch 17/25
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4567 - val_loss: 0.4483
# Epoch 18/25
# 235/235 [==============================] - 3s 11ms/step - loss: 0.4400 - val_loss: 0.4371
# Epoch 19/25
# 235/235 [==============================] - 3s 11ms/step - loss: 0.4431 - val_loss: 0.4497
# Epoch 20/25
# 235/235 [==============================] - 3s 11ms/step - loss: 0.4406 - val_loss: 0.4436
# Epoch 21/25
# 235/235 [==============================] - 3s 15ms/step - loss: 0.4414 - val_loss: 0.4470
# Epoch 22/25
# 235/235 [==============================] - 3s 11ms/step - loss: 0.4386 - val_loss: 0.4382
# Epoch 23/25
# 235/235 [==============================] - 3s 11ms/step - loss: 0.4317 - val_loss: 0.4360
# Epoch 24/25
# 235/235 [==============================] - 3s 11ms/step - loss: 0.4395 - val_loss: 0.4368
# Epoch 25/25
# 235/235 [==============================] - 3s 12ms/step - loss: 0.4424 - val_loss: 0.4376

# %%
# Predict and visualize one of the reconstructed test data
decoded_imgs = autoencoder.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original images
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28),cmap='gray')
    plt.title("Original")
    plt.axis('off')

    # Display reconstructed images
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28),cmap='gray')
    plt.title("Reconstructed")
    plt.axis('off')
plt.show()

# %%
# Visualize the loss and accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %% [markdown]
# **ADDING HIDDEN LAYER TO THE DENOISENING AUTOENCODER AND VISUALIZING THE DATA**

# %%
from keras.layers import Input, Dense
from keras.models import Model
import matplotlib.pyplot as plt
import numpy as np

# %%
encoding_dim = 32
hidden_dim = 64

# %%
# Input placeholder for noisy data
input_img = Input(shape=(784,))

# %%
# First Encoding Layer
encoded1 = Dense(hidden_dim, activation='relu')(input_img)

# Second Encoding Layer
encoded2 = Dense(encoding_dim, activation='relu')(encoded1)

# %%
# First Decoding layer
decoded1 = Dense(hidden_dim, activation='relu')(encoded2)

# Second Decoding layer
decoded2 = Dense(784, activation='sigmoid')(decoded1)

# %%
# Creating the denoising autoencoder model
autoencoder = Model(input_img, decoded2)

# %%
# Compiling the denoising autoencoder model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
# Loading and Preprocessing the data
from keras.datasets import fashion_mnist

(x_train, _), (x_test, _) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# %%
# Introducing Noise
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

# %%
# Train the Denoising Autoencoder
history = autoencoder.fit(x_train_noisy, x_train, epochs=20, batch_size=256, shuffle=True, validation_data=(x_test_noisy, x_test_noisy))
# Out:
# Epoch 1/20
# 235/235 [==============================] - 4s 12ms/step - loss: 0.3925 - val_loss: 0.3160
# Epoch 2/20
# 235/235 [==============================] - 3s 15ms/step - loss: 0.3216 - val_loss: 0.2994
# Epoch 3/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.3136 - val_loss: 0.2909
# Epoch 4/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.3092 - val_loss: 0.2847
# Epoch 5/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.3062 - val_loss: 0.2803
# Epoch 6/20
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3040 - val_loss: 0.2767
# Epoch 7/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.3025 - val_loss: 0.2747
# Epoch 8/20
# 235/235 [==============================] - 2s 11ms/step - loss: 0.3014 - val_loss: 0.2716
# Epoch 9/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.3002 - val_loss: 0.2694
# Epoch 10/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2993 - val_loss: 0.2674
# Epoch 11/20
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2985 - val_loss: 0.2658
# Epoch 12/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2978 - val_loss: 0.2645
# Epoch 13/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2972 - val_loss: 0.2631
# Epoch 14/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2967 - val_loss: 0.2620
# Epoch 15/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.2963 - val_loss: 0.2611
# Epoch 16/20
# 235/235 [==============================] - 3s 12ms/step - loss: 0.2959 - val_loss: 0.2597
# Epoch 17/20
# 235/235 [==============================] - 2s 11ms/step - loss: 0.2954 - val_loss: 0.2588
# Epoch 18/20
# 235/235 [==============================] - 2s 10ms/step - loss: 0.2951 - val_loss: 0.2581
# Epoch 19/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2948 - val_loss: 0.2572
# Epoch 20/20
# 235/235 [==============================] - 3s 15ms/step - loss: 0.2945 - val_loss: 0.2567

# %%
# Predict and visualize one of the reconstructed test data
decoded_imgs = autoencoder.predict(x_test_noisy)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
n = 10
plt.figure(figsize=(10, 30))
for i in range(n):
    # Display Noisy Images
    ax = plt.subplot(n, 3,i*3 + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28),cmap='gray')
    plt.title("Noisy")
    plt.axis('off')

    # Display Original Images
    ax = plt.subplot(n, 3, i*3 + 2)
    plt.imshow(x_test[i].reshape(28, 28),cmap='gray')
    plt.title("Original")
    plt.axis('off')

    # Display Reconstructed Images
    ax = plt.subplot(n,3, i*3 + 3)
    plt.imshow(decoded_imgs[i].reshape(28, 28),cmap='gray')
    plt.title("Reconstructed")
    plt.axis('off')

# %%
plt.show()

# %%
# Visualize the loss and accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
